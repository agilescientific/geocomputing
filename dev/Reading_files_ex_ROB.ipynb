# %% [markdown]
# # Reading data from files

# %%
import glob
import re
from collections import namedtuple

import numpy as np
import pandas as pd

import pint
ureg = pint.UnitRegistry()

# %%
#list files
uwis = glob.glob('../../data/reading_files/UWI*')
txts = [file for file in glob.glob('../../data/reading_files/*') if 'UWI' not in file]
wells = glob.glob('../../data/reading_files/*')

# %%
def make_lines_from_file(fname):
    """Make a list of all lines in a given file based on `fname` path"""
    with open(f'../../data/reading_files/{fname}', 'r') as f:
        return f.readlines()

# %%
def find_idxs(lines, comment='#'):
    """find the indexes of the Formation and Porosity headers given an input comment"""
    top_form = lines.index(f'{comment} Formations\n')
    top_pors = lines.index(f'{comment} Porosity\n')
    return top_form, top_pors

# %%
def get_units(lines):
    """Get the units from a lines object, parse the line and stop once a unit is found."""
    for line in lines:
        if 'units: m' in line.lower():
            units = 'm'
            break
        elif 'units: f' in line.lower():
            units = 'ft'
            break
        else:
            units = None
    return units

# %%
def find_kb(lines, comment='#'):
    """Use re to match a depth if `kb:` is the line."""
    pattern = r'\d{1,}.\d{0,}'
    for line in lines:
        if 'kb:' in line.lower():
            return re.findall(pattern, line)
    return None

# %%
def find_comment(lines):
    """Parse lines to find the first non-alpha and non-numeric character, assign this to comment."""
    for line in lines:
        if not line[0].isalpha() and not line[0].isdigit():
            comment = line[0]
            break
    return comment

# %%
def find_sep(lines):
    """Parse lines to find a charcter in the porosities (to limit other characters),
    that is not alphanumeric and is not a `.` nor newline character, assign this to the separator.
    """
    _, top_pors = find_idxs(lines, comment=find_comment(lines))
    sep = [char for char in lines[top_pors + 1] if not char.isalpha() 
                                                and not char.isdigit() 
                                                and char not in {'.', '\n'}]
    
    return sep[0]

# %%
def get_xy(lines, convert_units=True):
    """Use re to match a coordinates pattern if `loc` is found in the line.
    Unit conversion are made only from ft to m.
    """
    pattern = r'-?\d{1,}\.\d{1,}'
    coords = namedtuple('coords', 'x y')
    units = get_units(lines)
    for line in lines:
        if 'loc:' in line.lower():
            coords.x, coords.y = re.findall(pattern, line)
            break
    if convert_units and units == 'ft':
        x_ft = float(coords.x) * ureg.ft
        y_ft = float(coords.y) * ureg.ft
        x_m = x_ft.to(ureg.m).magnitude
        y_m = y_ft.to(ureg.m).magnitude
        return x_m, y_m
    else:
        return float(coords.x), float(coords.y)

# %%
def get_pors_from_lines(lines, top_pors, depth_units, poro_to_SI=False, sep=',', tvdss_from_md=False, kb=None):
    """Get porosities from file and convert units"""
    porosities = {}
    
    for line in lines[top_pors + 1:]:
        depth_str, poro_str = line.split(sep)
        
        try:
            depth = float(depth_str)
        except ValueError:
            depth = None
        if tvdss_from_md and kb:
            depth -= kb
            
        poro = float(poro_str)
        
        if poro_to_SI and depth_units == 'm':
            if poro < 1:
                poro *= 100
      
        porosities[depth] = poro
    
    return porosities

# %%
def read_tops_from_file(fname, 
                        null_vals=None,
                        keep_nulls=True,
                        convert_units=True,
                        poro_to_SI=False,
                        comment='#', 
                        sep=',', 
                        tvdss_from_md=False):
    """Read a single well file and extract formations and depths to a dictionary"""
    lines = make_lines_from_file(fname)
    top_form, top_pors = find_idxs(lines, comment)
    kb = float(find_kb(lines, comment=comment)[0])
    units = get_units(lines)

    tops = {}
    for line in lines[top_form + 1:top_pors]:
        name, depth_str = (line.split(sep))
        
        try:
            depth = float(depth_str)
        except ValueError:
            depth = null_vals
            
        if tvdss_from_md:
            depth -= kb
            
        if not keep_nulls:
            if depth == null_vals:
                continue
        
        if convert_units and units == 'ft':
            depth_ft = depth*ureg.ft
            depth = depth_ft.to(ureg.m).magnitude
        
        tops[name] = depth
    
    porosities = get_pors_from_lines(lines, 
                                     top_pors, 
                                     units, 
                                     poro_to_SI=poro_to_SI, 
                                     sep=sep, 
                                     tvdss_from_md=tvdss_from_md, 
                                     kb=kb
                                    )
    
        
    return tops, units, porosities

# %%
#fnames = ['UWI_4900521053.txt', 'UWI_4900523208.txt', 'UWI_4900522918.txt']
#for fname in fnames:
#    tops, units, porosities = read_tops_from_file(fname, poro_to_SI=True)
#    print(f'{80*"_"}\n{fname}\n{18*"="}\ntops:\n\n{tops}\n{18*"="}\nunits: {units}\n{18*"="}\nporosities:\n\n{porosities}\n{18*"="}\n')

# %%
#fname = '4900523357.txt'
#tops, units, porosities = read_tops_from_file(fname, comment='%', sep='\t', poro_to_SI=True, tvdss_from_md=True)
#print(f'{80*"_"}\n{fname}\n{18*"="}\ntops:\n\n{tops}\n{18*"="}\nunits: {units}\n{18*"="}\nporosities:\n\n{porosities}\n{18*"="}\n')

# %%
def parse_file(fname):
    """Parse file to extract metadata"""
    lines = make_lines_from_file(fname)
    comment = find_comment(lines)
    sep = find_sep(lines)
    x, y = get_xy(lines)
    return lines, comment, sep, x, y

# %%
def gather_all_wells(wells, verbose=False):
    ""
    all_tops = {}
    if verbose:
        print(f'Logging:\n{40*"="}')
    for well in wells:
        well_name = well.split('/')[-1]
        lines, comment, sep, x, y = parse_file(well)
        if verbose:
            print(f'\nWell name:\t{well_name}\ncomment:\t{comment}\nsep:\t\t{sep.__repr__()}\nx:\t\t{x}\ny:\t\t{y}')
        tops, units, porosities = read_tops_from_file(well,
                                                      comment=comment, 
                                                      sep=sep, 
                                                      poro_to_SI=True, 
                                                      tvdss_from_md=True)

        all_tops[well_name] = {'units': units,
                               'x': x,
                               'y': y,
                               'tops': tops,
                               'porosities': porosities}
    if verbose:
        print(f'\n{16*"="}\nall_tops created')
    return all_tops

# %%
all_tops = gather_all_wells(wells, verbose=False)
all_tops
# Out:
# {'UWI_4900527320.txt': {'units': 'ft',
#   'x': 40629.99849599999,
#   'y': -34852.999127999996,
#   'tops': {'Ardmore': 920.4959999999999,
#    'Sussex Upper Base': 940.0031999999999,
#    'Sussex Upper Top': 934.5167999999999,
#    'Cody': 929.0303999999999,
#    'Niobrara': 944.2703999999999,
#    'Sussex Lower Base': 943.6607999999999,
#    'Sussex Lower Top': 940.9175999999999},
#   'porosities': {3062.0: 7.5,
#    3064.0: 7.5,
#    3066.0: 12.0,
#    3067.0: 13.3,
#    3068.0: 12.0,
#    3070.0: 9.7,
#    3072.0: 10.3,
#    3074.0: 11.0,
#    3076.0: 12.0,
#    3078.0: 11.0,
#    3080.0: 10.0,
#    3082.0: 9.7,
#    3084.0: 9.2,
#    3086.0: 10.6,
#    3088.0: 5.0,
#    3090.0: 5.0,
#    3092.0: 12.2,
#    3094.0: 13.2,
#    3096.0: 8.0,
#    3098.0: 5.3,
#    3100.0: 4.2,
#    3102.0: 6.0,
#    3104.0: 6.2,
#    3106.0: 6.3,
#    3108.0: 6.0,
#    3110.0: 5.7,
#    3112.0: 5.5}},
#  'UWI_4900523333.txt': {'units': 'ft',
#   'x': 36110.000424,
#   'y': -29575.000031999996,
#   'tops': {'Ardmore': 930.2495999999999,
#    'Cody': 943.0511999999999,
#    'Sussex Upper Top': 943.0511999999999,
#    'Sussex Upper Base': 947.0135999999999,
#    'Niobrara': 949.1471999999999,
#    'Sussex Lower Top': -1853.5649999999998,
#    'Sussex Lower Base': -1853.5649999999998},
#   'porosities': {3088.0: 6.7,
#    3090.0: 7.68,
#    3092.0: 8.66,
#    3094.0: 8.66,
#    3096.0: 10.6,
#    3098.0: 13.5,
#    3100.0: 16.5,
#    3102.0: 15.0,
#    3104.0: 11.1,
#    3106.0: 8.66,
#    3108.0: 8.17,
#    3110.0: 6.7,
#    3112.0: 4.73,
#    3114.0: 6.21,
#    3116.0: 7.19,
#    3118.0: 6.7}},
#  '4900523357.txt': {'units': 'm',
#   'x': 36170.0,
#   'y': -30156.0,
#   'tops': {'Sussex Upper Base': 951.5900000000001,
#    'Sussex Upper Top': 947.6300000000001,
#    'Niobrara': 953.7200000000003,
#    'Cody': 947.3200000000002,
#    'Ardmore': 933.6100000000001,
#    'Sussex Lower Top': 953.4200000000001,
#    'Sussex Lower Base': 953.4200000000001},
#   'porosities': {945.4900000000002: 3.3000000000000003,
#    946.0999999999999: 0.8,
#    946.71: 0.3,
#    947.3200000000002: 1.0,
#    947.9300000000003: 1.3,
#    948.54: 8.9,
#    949.1500000000001: 9.4,
#    949.7600000000002: 5.800000000000001,
#    950.3699999999999: 4.8,
#    950.98: 7.9,
#    951.5900000000001: 2.3,
#    952.2000000000003: 2.3,
#    952.81: 1.0,
#    953.4200000000001: 2.3,
#    954.0300000000002: 1.3,
#    954.6399999999999: 1.0,
#    955.25: 1.0,
#    955.8600000000001: 0.3}},
#  'UWI_4900523389.txt': {'units': 'm',
#   'x': 36960.0,
#   'y': -30879.0,
#   'tops': {'Ardmore': 928.4199999999998,
#    'Cody': 942.1400000000001,
#    'Sussex Upper Top': 942.1400000000001,
#    'Sussex Lower Top': 945.49,
#    'Sussex Upper Base': 945.49,
#    'Niobrara': 948.2300000000002,
#    'Sussex Lower Base': 948.2300000000002},
#   'porosities': {939.7: 6.7,
#    940.3100000000002: 6.7,
#    940.9199999999998: 6.7,
#    941.53: 6.2,
#    942.1400000000001: 4.2,
#    942.7500000000002: 12.5,
#    943.3599999999999: 11.600000000000001,
#    943.9600000000003: 8.200000000000001,
#    944.5699999999999: 11.1,
#    945.1800000000001: 10.6,
#    945.7900000000002: 7.7,
#    946.3999999999999: 6.7,
#    947.01: 5.7,
#    947.6200000000001: 5.2,
#    948.2300000000002: 3.6999999999999997,
#    948.8399999999999: 4.7,
#    949.45: 5.2}},
#  '4900525111.txt': {'units': 'm',
#   'x': 38530.0,
#   'y': -28345.0,
#   'tops': {'Ardmore': 890.9299999999998,
#    'Cody': 904.3499999999999,
#    'Sussex Upper Top': 904.6500000000001,
#    'Sussex Upper Base': 909.2199999999998,
#    'Niobrara': 910.1399999999999,
#    'Sussex Lower Top': -2525.38,
#    'Sussex Lower Base': -2525.38},
#   'porosities': {903.1300000000001: 7.000000000000001,
#    903.7399999999998: 9.0,
#    904.3499999999999: 8.0,
#    904.9499999999998: 10.5,
#    905.56: 17.0,
#    906.1700000000001: 18.5,
#    906.7799999999997: 17.0,
#    907.3899999999999: 14.499999999999998,
#    908.0: 12.0,
#    908.6099999999997: 14.000000000000002,
#    909.2199999999998: 11.0,
#    909.8299999999999: 7.000000000000001,
#    910.44: 7.000000000000001,
#    911.0499999999997: 6.5}},
#  '4900525210.txt': {'units': 'm',
#   'x': 37825.0,
#   'y': -26378.0,
#   'tops': {'Ardmore': 890.6200000000001,
#    'Cody': 904.6400000000001,
#    'Sussex Upper Top': 904.95,
#    'Sussex Upper Base': 906.47,
#    'Niobrara': 907.99,
#    'Sussex Lower Top': -2514.7200000000003,
#    'Sussex Lower Base': -2514.7200000000003},
#   'porosities': {903.4199999999998: 8.5,
#    904.03: 9.0,
#    904.6400000000001: 11.0,
#    905.2499999999998: 15.5,
#    905.8599999999999: 13.5,
#    906.47: 12.0,
#    907.0800000000002: 8.5,
#    907.6899999999998: 7.000000000000001,
#    908.3: 6.5,
#    908.9100000000001: 5.0,
#    909.5199999999998: 5.0}},
#  '4900523595.txt': {'units': 'ft',
#   'x': 39595.001328,
#   'y': -32635.999751999996,
#   'tops': {'Ardmore': 911.0471999999999,
#    'Sussex Upper Top': 923.8487999999999,
#    'Cody': 924.1535999999999,
#    'Sussex Upper Base': 928.1159999999999,
#    'Sussex Lower Top': 929.3351999999999,
#    'Sussex Lower Base': 931.7735999999999,
#    'Niobrara': 933.6023999999999},
#   'porosities': {3025.0: 9.0,
#    3027.0: 8.0,
#    3029.0: 7.5,
#    3031.0: 8.5,
#    3033.0: 11.0,
#    3035.0: 13.0,
#    3037.0: 10.0,
#    3039.0: 12.0,
#    3041.0: 10.0,
#    3043.0: 9.0,
#    3045.0: 6.0,
#    3047.0: 5.0,
#    3049.0: 10.0,
#    3051.0: 11.0,
#    3053.0: 11.0,
#    3055.0: 12.5,
#    3057.0: 12.0,
#    3059.0: 8.5,
#    3061.0: 10.5,
#    3063.0: 6.0,
#    3065.0: 7.0,
#    3067.0: 7.0}},
#  '4900525200.txt': {'units': 'm',
#   'x': 37180.0,
#   'y': -29220.0,
#   'tops': {'Ardmore': 909.22,
#    'Sussex Upper Top': 922.6299999999999,
#    'Cody': 922.6299999999999,
#    'Sussex Lower Base': 928.1200000000001,
#    'Sussex Upper Base': 924.7699999999998,
#    'Sussex Lower Top': 925.0699999999999,
#    'Niobrara': 928.4300000000001},
#   'porosities': {923.55: 10.0,
#    924.1600000000001: 8.7,
#    924.7699999999998: 4.3,
#    925.3799999999999: 14.7,
#    925.99: 11.0,
#    926.6000000000001: 9.2,
#    927.2099999999998: 11.3,
#    927.8199999999999: 7.000000000000001,
#    928.4300000000001: 6.5,
#    929.0399999999997: 4.0,
#    929.6400000000001: 6.5,
#    930.2499999999998: 5.7,
#    930.8599999999999: 4.0}},
#  'UWI_4900525134.txt': {'units': 'm',
#   'x': 37730.0,
#   'y': -27569.0,
#   'tops': {'Ardmore': 897.6299999999999,
#    'Cody': 910.4399999999998,
#    'Sussex Upper Top': 910.4399999999998,
#    'Sussex Upper Base': 914.7,
#    'Niobrara': 915.01,
#    'Sussex Lower Top': -2534.5299999999997,
#    'Sussex Lower Base': -2534.5299999999997},
#   'porosities': {909.22: 7.5,
#    909.8300000000002: 9.0,
#    910.4399999999998: 12.0,
#    911.0400000000002: 7.000000000000001,
#    911.6499999999999: 13.0,
#    912.26: 12.0,
#    912.8700000000001: 10.5,
#    913.4800000000002: 9.5,
#    914.0899999999999: 10.0,
#    914.7: 8.0,
#    915.3100000000002: 5.5,
#    915.9199999999998: 7.000000000000001,
#    916.53: 5.0}},
#  'UWI_4900525116.txt': {'units': 'm',
#   'x': 37800.0,
#   'y': -26828.0,
#   'tops': {'Ardmore': 893.3699999999999,
#    'Cody': 902.8200000000002,
#    'Sussex Upper Top': 904.04,
#    'Sussex Upper Base': 906.7800000000002,
#    'Niobrara': 907.6999999999998,
#    'Sussex Lower Top': -2516.54,
#    'Sussex Lower Base': -2516.54},
#   'porosities': {902.21: 5.0,
#    902.8200000000002: 5.0,
#    903.4299999999998: 2.0,
#    904.04: 0.0,
#    904.6500000000001: 12.0,
#    905.2600000000002: 13.0,
#    905.8699999999999: 15.0,
#    906.48: 12.0,
#    907.0900000000001: 7.000000000000001,
#    907.6999999999998: 3.0,
#    908.31: 3.0,
#    908.9200000000001: 3.0,
#    909.5300000000002: 5.0,
#    910.1399999999999: 2.0}},
#  'UWI_4900523520.txt': {'units': 'm',
#   'x': 38015.0,
#   'y': -31830.0,
#   'tops': {'Ardmore': 925.0700000000002,
#    'Cody': 938.1700000000001,
#    'Sussex Upper Top': 939.7000000000003,
#    'Sussex Upper Base': 942.44,
#    'Niobrara': 945.4900000000002,
#    'Sussex Lower Base': 945.4900000000002,
#    'Sussex Lower Top': 945.4900000000002},
#   'porosities': {936.3499999999999: 4.2,
#    936.96: 2.8000000000000003,
#    937.5700000000002: 4.7,
#    938.1700000000001: 4.7,
#    938.7800000000002: 2.8000000000000003,
#    939.3900000000003: 1.7999999999999998,
#    940.0: 8.7,
#    940.6100000000001: 9.6,
#    941.2200000000003: 10.6,
#    941.8299999999999: 9.6,
#    942.44: 7.7,
#    943.0500000000002: 5.2,
#    943.6600000000003: 5.7,
#    944.27: 4.7,
#    944.8800000000001: 5.2,
#    945.4900000000002: 5.2,
#    946.0999999999999: 3.6999999999999997,
#    946.71: 3.3000000000000003,
#    947.3200000000002: 3.6999999999999997,
#    947.9300000000003: 2.3}},
#  '4900523683.txt': {'units': 'm',
#   'x': 41980.0,
#   'y': -32716.0,
#   'tops': {'Ardmore': 882.6999999999998,
#    'Sussex Upper Top': 896.4200000000001,
#    'Cody': 896.7199999999998,
#    'Sussex Upper Base': 897.6399999999999,
#    'Sussex Lower Top': 898.8600000000001,
#    'Sussex Lower Base': 902.21,
#    'Niobrara': 902.5099999999998},
#   'porosities': {895.81: 8.7,
#    896.4200000000001: 10.100000000000001,
#    897.0299999999997: 13.0,
#    897.6399999999999: 10.6,
#    898.25: 9.6,
#    898.8600000000001: 9.6,
#    899.4699999999998: 10.6,
#    900.0799999999999: 14.499999999999998,
#    900.6799999999998: 10.6,
#    901.29: 12.5,
#    901.9000000000001: 14.499999999999998,
#    902.5099999999998: 12.5,
#    903.1199999999999: 7.7,
#    903.73: 8.7,
#    904.3400000000001: 9.6,
#    904.9499999999998: 9.6,
#    905.56: 10.6}},
#  '4900525207.txt': {'units': 'm',
#   'x': 37770.0,
#   'y': -28463.0,
#   'tops': {'Sussex Lower Top': -2539.4,
#    'Niobrara': 916.23,
#    'Sussex Upper Base': 915.6199999999999,
#    'Sussex Upper Top': 911.0499999999997,
#    'Cody': 911.0499999999997,
#    'Ardmore': 898.25,
#    'Sussex Lower Base': -2539.4},
#   'porosities': {909.2199999999998: 6.0,
#    909.8299999999999: 7.5,
#    910.44: 6.0,
#    911.0499999999997: 8.0,
#    911.6599999999999: 9.0,
#    912.27: 9.5,
#    912.8800000000001: 5.0,
#    913.4899999999998: 9.0,
#    914.0999999999999: 8.0,
#    914.71: 9.0,
#    915.3199999999997: 7.000000000000001,
#    915.9299999999998: 5.5,
#    916.54: 4.0,
#    917.1500000000001: 5.0,
#    917.7599999999998: 5.0,
#    918.3699999999999: 6.0}},
#  '4900523535.txt': {'units': 'm',
#   'x': 41340.0,
#   'y': -34941.0,
#   'tops': {'Ardmore': 899.7700000000002,
#    'Cody': 912.8700000000001,
#    'Sussex Upper Base': 914.7,
#    'Sussex Upper Top': 914.7,
#    'Sussex Lower Top': 921.4100000000001,
#    'Sussex Lower Base': 921.7099999999998,
#    'Niobrara': 923.5400000000002},
#   'porosities': {911.0400000000002: 7.6,
#    911.6499999999999: 6.800000000000001,
#    912.26: 5.7,
#    912.8700000000001: 7.199999999999999,
#    913.4799999999998: 8.0,
#    914.0899999999999: 9.1,
#    914.7: 9.6,
#    915.3100000000002: 9.6,
#    915.9199999999998: 8.9,
#    916.53: 8.7,
#    917.1400000000001: 8.0,
#    917.7500000000002: 7.9,
#    918.3599999999999: 8.7,
#    918.97: 8.9,
#    919.5800000000002: 8.0,
#    920.1899999999998: 7.7,
#    920.8: 7.199999999999999,
#    921.4100000000001: 6.9,
#    922.0200000000002: 6.7,
#    922.6299999999999: 4.9,
#    923.24: 2.8000000000000003,
#    923.8500000000001: 3.5000000000000004,
#    924.4599999999998: 3.6999999999999997}},
#  'UWI_4900523138.txt': {'units': 'ft',
#   'x': 35329.998935999996,
#   'y': -28868.001191999992,
#   'tops': {'Ardmore': 931.4687999999999,
#    'Sussex Upper Top': 945.4895999999999,
#    'Cody': 945.7943999999999,
#    'Sussex Lower Base': 948.5375999999999,
#    'Sussex Lower Top': 948.5375999999999,
#    'Sussex Upper Base': 948.5375999999999,
#    'Niobrara': 950.9759999999999},
#   'porosities': {3096.0: 8.66,
#    3098.0: 8.66,
#    3100.0: 7.19,
#    3102.0: 7.19,
#    3104.0: 11.1,
#    3106.0: 13.5,
#    3108.0: 14.5,
#    3110.0: 12.5,
#    3112.0: 8.66,
#    3114.0: 10.1,
#    3116.0: 6.7,
#    3118.0: 7.68,
#    3120.0: 8.17,
#    3122.0: 7.19,
#    3124.0: 7.19,
#    3126.0: 7.19,
#    3128.0: 7.19}},
#  '4900523499.txt': {'units': 'ft',
#   'x': 37810.001088,
#   'y': -31219.999536,
#   'tops': {'Sussex Lower Base': 934.5167999999999,
#    'Ardmore': 915.3143999999999,
#    'Sussex Lower Top': 930.8591999999999,
#    'Niobrara': 934.8215999999999,
#    'Cody': 927.8111999999999,
#    'Sussex Upper Base': 930.8591999999999,
#    'Sussex Upper Top': 928.4207999999999},
#   'porosities': {3039.0: 10.4,
#    3041.0: 10.2,
#    3043.0: 9.94,
#    3045.0: 11.7,
#    3047.0: 16.7,
#    3049.0: 17.6,
#    3050.0: 15.0,
#    3051.0: 11.6,
#    3053.0: 9.94,
#    3055.0: 12.5,
#    3057.0: 11.6,
#    3059.0: 11.6,
#    3061.0: 10.8,
#    3063.0: 11.1,
#    3065.0: 9.64,
#    3067.0: 6.7}},
#  '4900523650.txt': {'units': 'ft',
#   'x': 40319.998607999994,
#   'y': -33328.999127999996,
#   'tops': {'Ardmore': 908.6087999999999,
#    'Cody': 921.4103999999999,
#    'Sussex Upper Top': 922.6295999999999,
#    'Sussex Upper Base': 926.8967999999999,
#    'Sussex Lower Top': 927.5063999999999,
#    'Sussex Lower Base': 930.5543999999999,
#    'Niobrara': 931.1639999999999},
#   'porosities': {3021.0: 7.0,
#    3023.0: 9.0,
#    3025.0: 13.0,
#    3027.0: 12.0,
#    3029.0: 16.0,
#    3031.0: 17.0,
#    3033.0: 14.0,
#    3035.0: 13.0,
#    3037.0: 12.5,
#    3039.0: 14.5,
#    3041.0: 13.5,
#    3043.0: 12.0,
#    3045.0: 12.5,
#    3047.0: 11.0,
#    3049.0: 7.0,
#    3051.0: 10.5,
#    3053.0: 12.5,
#    3055.0: 10.0,
#    3057.0: 6.0,
#    3059.0: 6.5,
#    3061.0: 7.0}},
#  'UWI_4900523603.txt': {'units': 'm',
#   'x': 40310.0,
#   'y': -32808.0,
#   'tops': {'Ardmore': 906.1699999999998,
#    'Cody': 918.6699999999998,
#    'Sussex Upper Top': 918.97,
#    'Sussex Upper Base': 923.5399999999997,
#    'Sussex Lower Top': 924.76,
#    'Sussex Lower Base': 928.1099999999999,
#    'Niobrara': 928.4199999999998},
#   'porosities': {918.0599999999997: 9.4,
#    918.6699999999998: 8.9,
#    919.28: 8.9,
#    919.8799999999999: 10.9,
#    920.49: 13.4,
#    921.1000000000001: 15.0,
#    921.7099999999998: 13.900000000000002,
#    922.3199999999999: 12.4,
#    922.9300000000001: 10.4,
#    923.5399999999997: 6.4,
#    924.1499999999999: 4.9,
#    924.76: 5.4,
#    925.3700000000001: 9.9,
#    925.9799999999998: 11.899999999999999,
#    926.5899999999999: 13.4,
#    927.2: 11.899999999999999,
#    927.8099999999997: 5.8999999999999995,
#    928.4199999999998: 4.3999999999999995,
#    929.03: 4.3999999999999995,
#    929.6400000000001: 5.8999999999999995}},
#  'UWI_4900523719.txt': {'units': 'm',
#   'x': 41180.0,
#   'y': -33392.0,
#   'tops': {'Ardmore': 898.2400000000002,
#    'Cody': 911.3499999999999,
#    'Sussex Upper Top': 913.48,
#    'Sussex Upper Base': 916.5300000000002,
#    'Sussex Lower Top': 917.44,
#    'Sussex Lower Base': 920.4900000000002,
#    'Niobrara': 921.0999999999999},
#   'porosities': {911.6500000000001: 10.6,
#    912.2600000000002: 12.5,
#    912.8699999999999: 12.1,
#    913.48: 13.200000000000001,
#    914.0900000000001: 16.2,
#    914.7000000000003: 14.099999999999998,
#    915.31: 13.5,
#    915.9200000000001: 13.0,
#    916.23: 9.9,
#    916.5300000000002: 11.600000000000001,
#    917.1400000000003: 11.899999999999999,
#    917.75: 8.7,
#    918.3600000000001: 10.6,
#    918.9700000000003: 14.499999999999998,
#    919.5799999999999: 19.7,
#    920.19: 19.400000000000002,
#    920.8000000000002: 13.5,
#    921.4100000000003: 9.6,
#    922.02: 9.8,
#    922.6300000000001: 10.6}},
#  'UWI_4900524791.txt': {'units': 'm',
#   'x': 47080.0,
#   'y': -39185.0,
#   'tops': {'Sussex Lower Top': -2525.38,
#    'Sussex Upper Base': -2525.38,
#    'Cody': 877.52,
#    'Sussex Lower Base': -2525.38,
#    'Niobrara': 886.9699999999998,
#    'Sussex Upper Top': -2525.38,
#    'Ardmore': 863.5},
#   'porosities': {876.9099999999999: 8.6,
#    877.2199999999998: 5.8999999999999995,
#    877.52: 6.5,
#    877.8299999999999: 10.100000000000001,
#    878.1300000000001: 13.4,
#    878.44: 14.6,
#    878.7399999999998: 12.1,
#    879.0499999999997: 10.100000000000001,
#    879.3499999999999: 13.8,
#    879.6599999999999: 11.1,
#    879.96: 13.0,
#    880.27: 12.5,
#    880.5699999999997: 14.899999999999999,
#    880.8800000000001: 12.6,
#    881.1799999999998: 12.1,
#    881.4899999999998: 10.7,
#    881.79: 9.8,
#    882.0899999999997: 10.8,
#    882.4000000000001: 9.700000000000001,
#    882.6999999999998: 3.8,
#    883.0099999999998: 3.4000000000000004,
#    883.31: 10.6}},
#  '4900524228.txt': {'units': 'ft',
#   'x': 40329.99909599999,
#   'y': -30222.998735999998,
#   'tops': {'Ardmore': 879.6527999999998,
#    'Cody': 893.6735999999999,
#    'Sussex Upper Top': 894.2831999999999,
#    'Sussex Upper Base': 898.8551999999999,
#    'Sussex Lower Base': 899.1599999999999,
#    'Niobrara': 899.4647999999999,
#    'Sussex Lower Top': 899.4647999999999},
#   'porosities': {2929.0: 2.77,
#    2931.0: 3.75,
#    2933.0: 5.71,
#    2935.0: 4.24,
#    2937.0: 4.24,
#    2939.0: 6.21,
#    2941.0: 12.5,
#    2943.0: 12.1,
#    2945.0: 11.6,
#    2947.0: 11.6,
#    2949.0: 8.66,
#    2951.0: 6.21,
#    2953.0: 5.22,
#    2955.0: 4.73,
#    2957.0: 3.26,
#    2959.0: 5.22,
#    2961.0: 2.77}},
#  'UWI_4900525199.txt': {'units': 'ft',
#   'x': 38139.99890399999,
#   'y': -29158.999847999996,
#   'tops': {'Sussex Lower Top': -1783.4609999999998,
#    'Ardmore': 953.4143999999999,
#    'Cody': 965.9111999999999,
#    'Niobrara': 972.0071999999999,
#    'Sussex Lower Base': -1783.4609999999998,
#    'Sussex Upper Top': 966.5207999999999,
#    'Sussex Upper Base': 970.4831999999999},
#   'porosities': {3162.0: 7.0,
#    3164.0: 5.7,
#    3166.0: 6.0,
#    3168.0: 2.0,
#    3170.0: 8.3,
#    3172.0: 12.0,
#    3174.0: 12.0,
#    3176.0: 11.0,
#    3178.0: 12.0,
#    3180.0: 10.0,
#    3182.0: 8.7,
#    3184.0: 7.2,
#    3186.0: 4.0,
#    3188.0: 5.7,
#    3190.0: 4.0,
#    3192.0: 3.8,
#    3194.0: 2.2}},
#  'UWI_4900523208.txt': {'units': 'ft',
#   'x': 35620.000896,
#   'y': -29315.999279999996,
#   'tops': {'Sussex Upper Base': 954.6335999999999,
#    'Ardmore': 935.7359999999999,
#    'Cody': 950.9759999999999,
#    'Sussex Lower Base': -1879.1681999999998,
#    'Niobrara': 956.4623999999999,
#    'Sussex Lower Top': -1879.1681999999998,
#    'Sussex Upper Top': 950.9759999999999},
#   'porosities': {3112.0: 9.64,
#    3114.0: 9.15,
#    3116.0: 6.21,
#    3118.0: 5.71,
#    3120.0: 6.7,
#    3122.0: 11.6,
#    3124.0: 14.5,
#    3126.0: 12.1,
#    3128.0: 12.1,
#    3130.0: 12.1,
#    3132.0: 8.17,
#    3134.0: 6.7,
#    3136.0: 7.68,
#    3138.0: 7.68,
#    3140.0: 7.19,
#    3142.0: 6.7}},
#  'UWI_4900527774.txt': {'units': 'ft',
#   'x': 43814.99999999999,
#   'y': -34366.99857599999,
#   'tops': {'Sussex Upper Base': -1796.8721999999998,
#    'Cody': 879.6527999999998,
#    'Ardmore': 868.0703999999998,
#    'Sussex Lower Top': 883.9199999999998,
#    'Niobrara': 889.4063999999998,
#    'Sussex Upper Top': -1796.8721999999998,
#    'Sussex Lower Base': 888.7967999999998},
#   'porosities': {2878.0: 18.4,
#    2880.0: 17.9,
#    2882.0: 18.4,
#    2884.0: 19.4,
#    2886.0: 16.5,
#    2888.0: 14.0,
#    2890.0: 16.5,
#    2892.0: 17.5,
#    2894.0: 12.5,
#    2896.0: 11.6,
#    2898.0: 11.6,
#    2900.0: 14.5,
#    2902.0: 16.5,
#    2904.0: 16.0,
#    2906.0: 15.0,
#    2908.0: 16.0,
#    2910.0: 16.5,
#    2912.0: 14.5,
#    2914.0: 16.0,
#    2916.0: 14.5,
#    2918.0: 11.6,
#    2920.0: 11.6,
#    2922.0: 10.1,
#    2924.0: 12.1}},
#  '4900523777.txt': {'units': 'm',
#   'x': 39500.0,
#   'y': -31934.0,
#   'tops': {'Ardmore': 908.6100000000001,
#    'Sussex Upper Top': 920.4900000000002,
#    'Cody': 920.8000000000002,
#    'Sussex Upper Base': 922.6300000000001,
#    'Sussex Lower Top': 923.8499999999999,
#    'Sussex Lower Base': 928.7200000000003,
#    'Niobrara': 929.94},
#   'porosities': {918.3600000000001: 6.7,
#    918.9700000000003: 4.7,
#    919.5799999999999: 5.2,
#    920.19: 6.7,
#    920.8000000000002: 13.0,
#    921.4099999999999: 12.5,
#    922.02: 9.6,
#    922.6300000000001: 10.6,
#    923.2400000000002: 6.7,
#    923.8499999999999: 9.2,
#    924.46: 10.6,
#    925.0700000000002: 6.2,
#    925.6799999999998: 8.7,
#    926.29: 10.100000000000001,
#    926.9000000000001: 8.200000000000001,
#    927.5: 9.6,
#    928.1100000000001: 7.7,
#    928.7200000000003: 4.2,
#    929.3299999999999: 2.8000000000000003,
#    929.94: 1.7999999999999998,
#    930.5500000000002: 2.8000000000000003}},
#  '4900524276.txt': {'units': 'ft',
#   'x': 39639.998951999994,
#   'y': -34086.000408,
#   'tops': {'Sussex Lower Top': 943.6607999999999,
#    'Sussex Lower Base': 944.5751999999999,
#    'Ardmore': 922.3247999999999,
#    'Sussex Upper Base': 942.4415999999999,
#    'Niobrara': 945.7943999999999,
#    'Cody': 935.1263999999999,
#    'Sussex Upper Top': 936.3455999999999},
#   'porosities': {3068.0: 6.0,
#    3070.0: 8.0,
#    3072.0: -1.0,
#    3074.0: 8.0,
#    3076.0: 7.5,
#    3078.0: 9.0,
#    3080.0: 9.0,
#    3082.0: 8.5,
#    3084.0: 8.5,
#    3086.0: 8.5,
#    3088.0: 8.0,
#    3090.0: 8.0,
#    3092.0: 4.0,
#    3094.0: 4.0,
#    3096.0: 7.0,
#    3098.0: 8.0,
#    3100.0: 4.5,
#    3102.0: 2.5,
#    3103.0: 2.0}},
#  'UWI_4900525239.txt': {'units': 'm',
#   'x': 37260.0,
#   'y': -25240.0,
#   'tops': {'Sussex Upper Base': 893.97,
#    'Ardmore': 874.47,
#    'Sussex Upper Top': 892.1499999999999,
#    'Cody': 892.1499999999999,
#    'Sussex Lower Top': -2522.34,
#    'Niobrara': 894.5800000000002,
#    'Sussex Lower Base': -2522.34},
#   'porosities': {890.9300000000001: 7.5,
#    891.5400000000002: 5.0,
#    892.1499999999999: 8.0,
#    892.7500000000002: 13.5,
#    893.3599999999999: 13.0,
#    893.97: 12.0,
#    894.5800000000002: 9.0,
#    895.1900000000003: 8.5,
#    895.8: 3.5000000000000004,
#    896.4100000000001: 10.0,
#    897.0200000000002: 7.5}},
#  'UWI_4900524005.txt': {'units': 'ft',
#   'x': 40190.00140799999,
#   'y': -31218.999791999995,
#   'tops': {'Ardmore': 895.1975999999999,
#    'Cody': 904.9511999999999,
#    'Sussex Upper Top': 905.5607999999999,
#    'Sussex Upper Base': 907.6943999999999,
#    'Sussex Lower Top': 909.2183999999999,
#    'Sussex Lower Base': 912.5711999999999,
#    'Niobrara': 912.8759999999999},
#   'porosities': {2965.0: 6.7,
#    2967.0: 7.68,
#    2969.0: 8.17,
#    2971.0: 10.6,
#    2973.0: 10.6,
#    2975.0: 10.6,
#    2977.0: 7.68,
#    2979.0: 4.24,
#    2981.0: 9.64,
#    2983.0: 11.6,
#    2985.0: 14.5,
#    2987.0: 14.5,
#    2989.0: 14.0,
#    2991.0: 12.5,
#    2993.0: 8.17,
#    2995.0: 4.73,
#    2997.0: 4.73,
#    2999.0: 5.22,
#    3001.0: 5.22}},
#  'UWI_4900523972.txt': {'units': 'ft',
#   'x': 38569.998552,
#   'y': -30353.998727999995,
#   'tops': {'Ardmore': 904.6463999999999,
#    'Cody': 917.7527999999999,
#    'Sussex Upper Top': 917.7527999999999,
#    'Sussex Lower Top': 920.8007999999999,
#    'Sussex Upper Base': 920.8007999999999,
#    'Sussex Lower Base': 923.2391999999999,
#    'Niobrara': 925.0679999999999},
#   'porosities': {3004.0: 6.21,
#    3006.0: 3.75,
#    3008.0: 5.71,
#    3010.0: 7.19,
#    3012.0: 7.19,
#    3014.0: 10.6,
#    3016.0: 12.5,
#    3018.0: 12.5,
#    3020.0: 11.6,
#    3022.0: 12.5,
#    3024.0: 9.64,
#    3026.0: 9.15,
#    3028.0: 8.66,
#    3030.0: 6.21,
#    3032.0: 6.21,
#    3034.0: 5.71,
#    3036.0: 4.73,
#    3038.0: 3.26,
#    3040.0: 1.79,
#    3042.0: 4.24,
#    3044.0: 4.24,
#    3046.0: 5.71,
#    3048.0: 4.73}},
#  'UWI_4900523444.txt': {'units': 'ft',
#   'x': 38759.99868,
#   'y': -31894.000727999995,
#   'tops': {'Sussex Lower Base': 931.4687999999999,
#    'Cody': 923.2391999999999,
#    'Sussex Upper Top': 923.5439999999999,
#    'Ardmore': 911.3519999999999,
#    'Sussex Lower Top': 929.6399999999999,
#    'Niobrara': 931.4687999999999,
#    'Sussex Upper Base': 929.6399999999999},
#   'porosities': {3022.0: 9.41,
#    3024.0: 7.88,
#    3026.0: 11.4,
#    3028.0: 12.9,
#    3030.0: 10.4,
#    3032.0: 8.9,
#    3034.0: 8.9,
#    3036.0: 13.9,
#    3038.0: 14.5,
#    3040.0: 13.4,
#    3042.0: 12.4,
#    3044.0: 11.4,
#    3046.0: 11.4,
#    3048.0: 11.4,
#    3050.0: 7.88,
#    3052.0: 7.38,
#    3054.0: 5.34,
#    3056.0: 4.32}},
#  'UWI_4900525135.txt': {'units': 'ft',
#   'x': 38540.000135999995,
#   'y': -27146.999807999997,
#   'tops': {'Ardmore': 884.2247999999998,
#    'Cody': 897.9407999999999,
#    'Sussex Upper Top': 898.2455999999999,
#    'Sussex Upper Base': 900.9887999999999,
#    'Niobrara': 901.5983999999999,
#    'Sussex Lower Top': -1813.9409999999998,
#    'Sussex Lower Base': -1813.9409999999998},
#   'porosities': {2942.0: 6.5,
#    2944.0: 3.5,
#    2946.0: 2.5,
#    2948.0: 9.0,
#    2950.0: 11.0,
#    2952.0: 14.0,
#    2954.0: 12.0,
#    2956.0: 11.0,
#    2958.0: 4.0,
#    2960.0: 4.0,
#    2962.0: 2.0,
#    2964.0: 3.0}},
#  '4900523649.txt': {'units': 'ft',
#   'x': 41180.000951999995,
#   'y': -32723.998559999996,
#   'tops': {'Ardmore': 893.6735999999999,
#    'Cody': 907.3895999999999,
#    'Sussex Upper Top': 907.9991999999999,
#    'Sussex Upper Base': 912.5711999999999,
#    'Sussex Lower Top': 913.4855999999999,
#    'Sussex Lower Base': 915.6191999999999,
#    'Niobrara': 915.9239999999999},
#   'porosities': {2973.0: 7.19,
#    2975.0: 10.6,
#    2977.0: 9.64,
#    2979.0: 11.6,
#    2981.0: 12.5,
#    2983.0: 13.5,
#    2985.0: 15.5,
#    2987.0: 14.5,
#    2989.0: 13.5,
#    2991.0: 6.7,
#    2993.0: 9.64,
#    2995.0: 13.5,
#    2997.0: 17.0,
#    2999.0: 17.5,
#    3001.0: 13.5,
#    3003.0: 13.0,
#    3005.0: 10.6,
#    3007.0: 8.66}},
#  '4900525166.txt': {'units': 'ft',
#   'x': 36930.00081599999,
#   'y': -26729.000136,
#   'tops': {'Ardmore': 890.0159999999998,
#    'Cody': 900.6839999999999,
#    'Sussex Upper Top': 901.9031999999999,
#    'Sussex Upper Base': 904.3415999999999,
#    'Niobrara': 906.7799999999999,
#    'Sussex Lower Top': -1824.6089999999997,
#    'Sussex Lower Base': -1824.6089999999997},
#   'porosities': {2959.0: 2.3,
#    2961.0: 3.2,
#    2963.0: 5.5,
#    2965.0: 0.0,
#    2967.0: 4.0,
#    2969.0: 4.2,
#    2971.0: 5.3,
#    2973.0: 4.2,
#    2975.0: 3.7,
#    2977.0: 0.0,
#    2979.0: 2.0,
#    2981.0: 0.5,
#    2983.0: 0.1}},
#  'UWI_4900525104.txt': {'units': 'm',
#   'x': 38940.0,
#   'y': -29139.0,
#   'tops': {'Sussex Upper Base': 906.48,
#    'Sussex Upper Top': 903.1300000000001,
#    'Cody': 901.5999999999999,
#    'Sussex Lower Base': 907.3899999999999,
#    'Ardmore': 892.1500000000001,
#    'Sussex Lower Top': 906.48,
#    'Niobrara': 908.31},
#   'porosities': {900.3800000000001: 2.0,
#    900.9899999999998: 7.000000000000001,
#    901.5999999999999: 7.000000000000001,
#    902.21: 2.0,
#    902.8200000000002: 3.0,
#    903.4299999999998: 14.000000000000002,
#    904.04: 14.000000000000002,
#    904.6500000000001: 13.0,
#    905.2599999999998: 16.0,
#    905.8699999999999: 16.0,
#    906.48: 14.000000000000002,
#    907.0900000000001: 14.000000000000002,
#    907.6999999999998: 11.0,
#    908.31: 4.0,
#    908.9200000000001: 5.0,
#    909.5300000000002: 6.0,
#    910.1399999999999: 4.0,
#    910.75: 4.0,
#    911.3499999999999: 4.0}},
#  'UWI_4900523570.txt': {'units': 'm',
#   'x': 38990.0,
#   'y': -32474.0,
#   'tops': {'Ardmore': 916.23,
#    'Cody': 928.1199999999999,
#    'Sussex Upper Top': 928.4200000000001,
#    'Sussex Lower Top': 933.5999999999999,
#    'Sussex Upper Base': 933.5999999999999,
#    'Sussex Lower Base': 936.96,
#    'Niobrara': 937.2600000000002},
#   'porosities': {926.5900000000001: 5.0,
#    927.1999999999998: 8.0,
#    927.81: 8.0,
#    928.4200000000001: 8.0,
#    929.0300000000002: 13.0,
#    929.6399999999999: 11.0,
#    930.25: 14.000000000000002,
#    930.8600000000001: 15.5,
#    931.4699999999998: 15.0,
#    932.0799999999999: 14.499999999999998,
#    932.69: 15.0,
#    933.3000000000002: 13.0,
#    933.9099999999999: 11.0,
#    934.52: 9.5,
#    935.1300000000001: 9.0,
#    935.7399999999998: 9.0,
#    936.3499999999999: 8.0,
#    936.96: 9.0,
#    937.5700000000002: 6.5,
#    938.1799999999998: 7.000000000000001,
#    938.7800000000002: 7.000000000000001}},
#  'UWI_4900524202.txt': {'units': 'ft',
#   'x': 39459.99931199999,
#   'y': -30265.000175999994,
#   'tops': {'Ardmore': 891.2351999999998,
#    'Cody': 904.3415999999999,
#    'Sussex Upper Top': 904.3415999999999,
#    'Sussex Upper Base': 906.7799999999999,
#    'Sussex Lower Top': 907.0847999999999,
#    'Sussex Lower Base': 910.1327999999999,
#    'Niobrara': 911.6567999999999},
#   'porosities': {2959.0: 7.19,
#    2961.0: 6.21,
#    2963.0: 6.7,
#    2965.0: 5.71,
#    2967.0: 9.64,
#    2969.0: 14.0,
#    2971.0: 12.5,
#    2973.0: 9.15,
#    2975.0: 4.24,
#    2977.0: 9.64,
#    2979.0: 14.0,
#    2981.0: 5.71,
#    2983.0: 10.1,
#    2985.0: 16.0,
#    2987.0: 12.1,
#    2989.0: 6.21,
#    2991.0: 4.24,
#    2993.0: 4.73,
#    2995.0: 5.71,
#    2997.0: 5.71,
#    2999.0: 3.75}},
#  'UWI_4900521053.txt': {'units': 'ft',
#   'x': 35320.001496,
#   'y': -27701.001239999998,
#   'tops': {'Ardmore': 923.5439999999999,
#    'Cody': 936.6503999999999,
#    'Sussex Upper Base': 937.2599999999999,
#    'Sussex Upper Top': 937.2599999999999,
#    'Sussex Lower Base': 937.8695999999999,
#    'Sussex Lower Top': 937.8695999999999,
#    'Niobrara': 941.5271999999999},
#   'porosities': {3071.0: 6.0,
#    3073.0: 2.0,
#    3075.0: 3.0,
#    3077.0: 7.0,
#    3079.0: 7.0,
#    3081.0: 9.0,
#    3083.0: 10.0,
#    3085.0: 8.0,
#    3087.0: 3.0,
#    3089.0: 8.0,
#    3091.0: 14.5,
#    3093.0: 6.0,
#    3095.0: 5.0,
#    3097.0: 6.0,
#    3099.0: 7.5,
#    3101.0: 5.5,
#    3103.0: 15.0,
#    3105.0: 11.0,
#    3107.0: 5.5,
#    3109.0: 5.0,
#    3111.0: 2.0,
#    3113.0: 4.0,
#    3115.0: 7.0,
#    3117.0: 5.0,
#    3119.0: 5.0,
#    3121.0: 3.5,
#    3123.0: 6.0,
#    3125.0: 9.5,
#    3127.0: 9.0,
#    3129.0: 7.5}},
#  'UWI_4900523631.txt': {'units': 'ft',
#   'x': 39690.00139199999,
#   'y': -33268.99924799999,
#   'tops': {'Cody': 928.4207999999999,
#    'Sussex Upper Top': 928.4207999999999,
#    'Sussex Lower Top': 933.9071999999999,
#    'Niobrara': 938.1743999999999,
#    'Sussex Upper Base': 933.2975999999999,
#    'Sussex Lower Base': 936.6503999999999,
#    'Ardmore': 915.3143999999999},
#   'porosities': {3038.0: 5.0,
#    3040.0: 3.0,
#    3042.0: 1.0,
#    3044.0: 3.0,
#    3046.0: 12.0,
#    3048.0: 10.0,
#    3050.0: 11.0,
#    3052.0: 11.5,
#    3054.0: 12.0,
#    3056.0: 12.5,
#    3058.0: 11.0,
#    3060.0: 12.0,
#    3062.0: 10.0,
#    3064.0: 10.5,
#    3066.0: 9.5,
#    3068.0: 12.0,
#    3070.0: 11.5,
#    3072.0: 9.0,
#    3074.0: 9.0,
#    3076.0: 10.0,
#    3078.0: 7.0,
#    3080.0: 6.0,
#    3082.0: 3.0,
#    3084.0: 3.0,
#    3086.0: 5.5}},
#  '4900524277.txt': {'units': 'ft',
#   'x': 41050.000704,
#   'y': -31175.998607999998,
#   'tops': {'Ardmore': 883.6151999999998,
#    'Cody': 897.6359999999999,
#    'Sussex Upper Top': 897.9407999999999,
#    'Sussex Upper Base': 900.3791999999999,
#    'Sussex Lower Top': 901.2935999999999,
#    'Sussex Lower Base': 903.4271999999999,
#    'Niobrara': 904.0367999999999},
#   'porosities': {2938.0: 7.68,
#    2940.0: 6.7,
#    2942.0: 4.73,
#    2944.0: 5.22,
#    2946.0: 7.68,
#    2948.0: 12.5,
#    2950.0: 9.64,
#    2952.0: 3.75,
#    2954.0: 5.22,
#    2956.0: 3.26,
#    2958.0: 5.71,
#    2960.0: 10.6,
#    2962.0: 12.5,
#    2964.0: 7.68,
#    2966.0: 4.73,
#    2968.0: 7.68,
#    2970.0: 4.24}},
#  'UWI_4900523633.txt': {'units': 'm',
#   'x': 41980.0,
#   'y': -33510.0,
#   'tops': {'Sussex Lower Top': 901.6000000000001,
#    'Niobrara': 904.6500000000003,
#    'Sussex Upper Top': 899.47,
#    'Sussex Upper Base': 901.3,
#    'Sussex Lower Base': 904.6500000000003,
#    'Cody': 898.2500000000002,
#    'Ardmore': 883.6200000000001},
#   'porosities': {897.6400000000001: 7.7,
#    898.2500000000002: 8.7,
#    898.8599999999999: 9.9,
#    899.47: 11.600000000000001,
#    900.0800000000002: 12.6,
#    900.6900000000003: 10.299999999999999,
#    901.3: 9.5,
#    901.9100000000001: 11.899999999999999,
#    902.5200000000002: 15.5,
#    903.1299999999999: 15.8,
#    903.7300000000002: 12.1,
#    904.3399999999999: 11.600000000000001,
#    904.95: 5.2,
#    905.5600000000002: 6.7,
#    906.1700000000003: 11.3,
#    906.78: 8.0,
#    907.3900000000001: 8.0,
#    908.0000000000002: 7.000000000000001}},
#  'UWI_4900523863.txt': {'units': 'm',
#   'x': 37780.0,
#   'y': -30287.0,
#   'tops': {'Ardmore': 914.7099999999998,
#    'Cody': 927.2,
#    'Sussex Upper Top': 928.1200000000001,
#    'Sussex Upper Base': 931.7700000000002,
#    'Niobrara': 934.2099999999998,
#    'Sussex Lower Top': -2530.26,
#    'Sussex Lower Base': -2530.26},
#   'porosities': {925.6800000000001: 7.5,
#    926.2900000000002: 8.0,
#    926.8999999999999: 9.0,
#    927.51: 8.5,
#    928.1200000000001: 10.0,
#    928.7299999999998: 10.5,
#    929.3399999999999: 10.0,
#    929.95: 9.5,
#    930.55: 9.5,
#    931.1600000000001: 9.5,
#    931.7700000000002: 7.000000000000001,
#    932.3799999999999: 6.5,
#    932.99: 5.5,
#    933.6000000000001: 5.0,
#    934.2099999999998: 4.5,
#    934.8199999999999: 4.0,
#    935.4300000000001: 3.5000000000000004,
#    936.0400000000002: 4.0}},
#  'UWI_4900524816.txt': {'units': 'ft',
#   'x': 40990.000823999995,
#   'y': -30395.000423999998,
#   'tops': {'Ardmore': 877.8239999999998,
#    'Cody': 892.1495999999999,
#    'Sussex Upper Top': 893.6735999999999,
#    'Sussex Upper Base': 894.2831999999999,
#    'Sussex Lower Top': 896.1119999999999,
#    'Sussex Lower Base': 896.4167999999999,
#    'Niobrara': 897.6359999999999},
#   'porosities': {2930.0: 7.0,
#    2932.0: 8.0,
#    2934.0: 9.0,
#    2936.0: 8.5,
#    2938.0: 7.0,
#    2940.0: 9.0,
#    2942.0: 9.0,
#    2944.0: 7.0,
#    2946.0: 5.0,
#    2948.0: 7.0,
#    2950.0: 7.0,
#    2952.0: 4.0,
#    2954.0: 5.0,
#    2956.0: 5.0}},
#  'UWI_4900523013.txt': {'units': 'm',
#   'x': 38190.0,
#   'y': -32884.0,
#   'tops': {'Ardmore': 932.6900000000003,
#    'Cody': 944.2700000000002,
#    'Sussex Upper Top': 944.2700000000002,
#    'Sussex Lower Top': 950.3700000000001,
#    'Sussex Lower Base': 951.28,
#    'Sussex Upper Base': 952.2,
#    'Niobrara': 953.4100000000001},
#   'porosities': {943.97: 18.4,
#    944.5800000000002: 21.9,
#    945.1800000000001: 14.499999999999998,
#    945.7900000000002: 15.0,
#    946.3999999999999: 13.5,
#    947.01: 12.5,
#    947.6200000000001: 14.000000000000002,
#    948.2300000000002: 15.5,
#    948.8399999999999: 15.5,
#    949.45: 14.000000000000002,
#    950.0600000000002: 16.0,
#    950.6700000000003: 12.5,
#    951.28: 10.6,
#    951.8900000000001: 5.7,
#    952.5000000000002: 8.7,
#    953.1099999999999: 6.7,
#    953.72: 8.7,
#    954.3300000000002: 9.6}},
#  'UWI_4900525209.txt': {'units': 'ft',
#   'x': 37265.0004,
#   'y': -25979.000111999998,
#   'tops': {'Ardmore': 883.9199999999998,
#    'Cody': 897.6359999999999,
#    'Sussex Upper Top': 897.9407999999999,
#    'Sussex Upper Base': 900.9887999999999,
#    'Niobrara': 901.2935999999999,
#    'Sussex Lower Top': -1821.5609999999997,
#    'Sussex Lower Base': -1821.5609999999997},
#   'porosities': {2941.0: 9.5,
#    2943.0: 10.0,
#    2945.0: 6.0,
#    2947.0: 4.0,
#    2949.0: 17.0,
#    2951.0: 14.0,
#    2953.0: 14.0,
#    2955.0: 11.0,
#    2957.0: 6.0,
#    2959.0: 7.0,
#    2961.0: 6.0,
#    2963.0: 4.0}},
#  'UWI_4900525287.txt': {'units': 'm',
#   'x': 36520.0,
#   'y': -25197.0,
#   'tops': {'Sussex Upper Top': 902.8199999999999,
#    'Sussex Lower Top': -2554.34,
#    'Sussex Lower Base': -2554.34,
#    'Cody': 902.51,
#    'Niobrara': 904.6499999999999,
#    'Sussex Upper Base': 903.4300000000001,
#    'Ardmore': 888.1900000000003},
#   'porosities': {900.99: 5.0,
#    901.6000000000001: 5.5,
#    902.2100000000003: 4.0,
#    902.8199999999999: 5.0,
#    903.4300000000001: 9.0,
#    904.0400000000002: 8.0,
#    904.6499999999999: 7.000000000000001,
#    905.26: 3.0,
#    905.8700000000001: 4.0,
#    906.47: 3.0}},
#  'UWI_4900523964.txt': {'units': 'm',
#   'x': 41030.0,
#   'y': -32057.0,
#   'tops': {'Sussex Lower Base': 913.7900000000002,
#    'Niobrara': 914.7,
#    'Ardmore': 892.76,
#    'Sussex Lower Top': 911.6499999999999,
#    'Cody': 906.78,
#    'Sussex Upper Base': 910.1299999999999,
#    'Sussex Upper Top': 907.6899999999998},
#   'porosities': {904.6400000000001: 7.000000000000001,
#    905.2500000000002: 8.0,
#    905.8599999999999: 7.5,
#    906.47: 6.0,
#    907.0800000000002: 8.5,
#    907.6899999999998: 11.0,
#    908.3: 10.0,
#    908.9100000000001: 13.0,
#    909.5200000000002: 11.5,
#    910.1299999999999: 3.0,
#    910.74: 4.0,
#    911.3500000000001: 10.5,
#    911.9600000000003: 12.5,
#    912.5699999999999: 11.5,
#    913.1800000000001: 6.0,
#    913.7900000000002: 16.5,
#    914.3999999999999: 12.0,
#    915.01: 6.0,
#    915.6200000000001: 5.5}},
#  'UWI_4900523827.txt': {'units': 'm',
#   'x': 41015.0,
#   'y': -34055.0,
#   'tops': {'Ardmore': 906.4799999999998,
#    'Cody': 919.5800000000002,
#    'Sussex Upper Top': 920.4999999999998,
#    'Sussex Upper Base': 925.6800000000001,
#    'Sussex Lower Top': 926.8999999999999,
#    'Sussex Lower Base': 929.3399999999999,
#    'Niobrara': 929.95},
#   'porosities': {917.7499999999998: 7.9,
#    918.3599999999999: 7.3999999999999995,
#    918.97: 5.3,
#    919.5800000000002: 7.3999999999999995,
#    920.1899999999998: 5.3,
#    920.8: 11.4,
#    921.4100000000001: 9.4,
#    922.0200000000002: 8.4,
#    922.6299999999999: 11.4,
#    923.24: 11.4,
#    923.8500000000001: 9.9,
#    924.4599999999998: 11.899999999999999,
#    925.0699999999999: 8.4,
#    925.6800000000001: 8.9,
#    926.2900000000002: 7.3999999999999995,
#    926.8999999999999: 1.3,
#    927.51: 7.9,
#    928.1200000000001: 9.4,
#    928.7299999999998: 11.4,
#    929.3399999999999: 12.4,
#    929.95: 5.800000000000001,
#    930.55: 5.3}},
#  '4900524006.txt': {'units': 'ft',
#   'x': 40230.000312,
#   'y': -34059.001224,
#   'tops': {'Ardmore': 916.8383999999999,
#    'Sussex Lower Top': 936.0407999999999,
#    'Sussex Lower Base': 938.4791999999999,
#    'Sussex Upper Top': 928.7255999999999,
#    'Niobrara': 939.0887999999999,
#    'Sussex Upper Base': 935.4311999999999,
#    'Cody': 928.1159999999999},
#   'porosities': {3041.0: 8.66,
#    3043.0: 6.7,
#    3045.0: 6.7,
#    3047.0: 7.68,
#    3049.0: 9.15,
#    3051.0: 14.0,
#    3053.0: 12.1,
#    3055.0: 14.5,
#    3057.0: 14.5,
#    3059.0: 9.64,
#    3061.0: 8.66,
#    3063.0: 8.66,
#    3065.0: 10.6,
#    3067.0: 10.6,
#    3069.0: 9.15,
#    3071.0: 2.77,
#    3073.0: 2.77,
#    3075.0: 10.6,
#    3077.0: 14.5,
#    3079.0: 11.6,
#    3081.0: 8.17,
#    3083.0: 6.21,
#    3085.0: 5.22,
#    3087.0: 5.22,
#    3089.0: 4.24,
#    3091.0: 4.73}},
#  '4900523753.txt': {'units': 'ft',
#   'x': 42110.000616,
#   'y': -34183.999703999994,
#   'tops': {'Ardmore': 887.5775999999998,
#    'Cody': 900.6839999999999,
#    'Sussex Upper Base': 903.1223999999999,
#    'Sussex Upper Top': 903.1223999999999,
#    'Sussex Lower Top': 905.2559999999999,
#    'Sussex Lower Base': 907.6943999999999,
#    'Niobrara': 907.9991999999999},
#   'porosities': {2955.0: 9.15,
#    2957.0: 9.64,
#    2959.0: 9.15,
#    2961.0: 8.66,
#    2963.0: 8.66,
#    2965.0: 7.68,
#    2967.0: 8.66,
#    2969.0: 9.64,
#    2971.0: 12.1,
#    2973.0: 12.5,
#    2975.0: 12.1,
#    2977.0: 9.64,
#    2979.0: 8.66,
#    2981.0: 8.17,
#    2983.0: 9.64,
#    2985.0: 8.17,
#    2987.0: 6.7,
#    2989.0: 6.7,
#    2991.0: 8.17}},
#  '4900525133.txt': {'units': 'm',
#   'x': 39330.0,
#   'y': -27493.0,
#   'tops': {'Sussex Lower Top': -2499.48,
#    'Sussex Lower Base': -2499.48,
#    'Cody': 888.4899999999998,
#    'Ardmore': 877.8200000000002,
#    'Sussex Upper Top': 889.4000000000001,
#    'Sussex Upper Base': 890.6199999999999,
#    'Niobrara': 891.23},
#   'porosities': {887.8800000000001: 6.0,
#    888.1799999999998: 7.1,
#    888.4899999999998: 5.5,
#    888.79: 11.5,
#    889.0999999999999: 13.600000000000001,
#    889.4000000000001: 15.5,
#    889.71: 7.3999999999999995,
#    890.0099999999998: 14.099999999999998,
#    890.3200000000002: 13.700000000000001,
#    890.6199999999999: 13.200000000000001}},
#  '4900523816.txt': {'units': 'm',
#   'x': 38990.0,
#   'y': -33285.0,
#   'tops': {'Ardmore': 926.9000000000001,
#    'Cody': 939.4000000000001,
#    'Sussex Upper Top': 939.4000000000001,
#    'Sussex Lower Top': 945.19,
#    'Sussex Upper Base': 945.19,
#    'Sussex Lower Base': 947.02,
#    'Niobrara': 949.46},
#   'porosities': {937.8699999999999: 7.000000000000001,
#    938.48: 7.5,
#    939.0899999999997: 5.5,
#    939.6999999999998: 11.0,
#    940.31: 11.0,
#    940.9200000000001: 12.5,
#    941.5299999999997: 12.0,
#    942.1399999999999: 11.5,
#    942.75: 12.0,
#    943.3599999999997: 11.0,
#    943.9699999999998: 13.0,
#    944.5799999999999: 13.0,
#    945.19: 11.5,
#    945.7999999999997: 7.5,
#    946.4099999999999: 9.0,
#    947.02: 8.5,
#    947.6300000000001: 8.0,
#    948.2399999999998: 7.000000000000001,
#    948.8499999999999: 5.5,
#    949.46: 4.0,
#    950.0699999999997: 6.5,
#    950.6799999999998: 6.5,
#    951.29: 7.000000000000001,
#    951.8899999999999: 7.000000000000001}},
#  '4900523478.txt': {'units': 'ft',
#   'x': 36959.999231999995,
#   'y': -30417.000887999995,
#   'tops': {'Ardmore': 925.0679999999999,
#    'Cody': 936.9551999999999,
#    'Sussex Upper Top': 936.9551999999999,
#    'Sussex Upper Base': 939.0887999999999,
#    'Niobrara': 943.0511999999999,
#    'Sussex Lower Top': -1856.0033999999998,
#    'Sussex Lower Base': -1856.0033999999998},
#   'porosities': {3068.0: 5.34,
#    3070.0: 2.29,
#    3072.0: 4.32,
#    3074.0: 9.41,
#    3076.0: 10.9,
#    3078.0: 7.88,
#    3080.0: 6.36,
#    3082.0: 5.85,
#    3084.0: 4.32,
#    3086.0: 4.32,
#    3088.0: 4.32,
#    3090.0: 4.32,
#    3092.0: 4.32,
#    3094.0: 3.81}},
#  'UWI_4900522918.txt': {'units': 'm',
#   'x': 35580.0,
#   'y': -30228.0,
#   'tops': {'Ardmore': 941.22,
#    'Cody': 954.9400000000003,
#    'Sussex Upper Top': 957.0699999999999,
#    'Sussex Lower Base': 960.1200000000001,
#    'Sussex Lower Top': 960.1200000000001,
#    'Sussex Upper Base': 960.1200000000001,
#    'Niobrara': 961.95},
#   'porosities': {954.03: 6.2,
#    954.6400000000001: 7.199999999999999,
#    955.2500000000002: 5.7,
#    955.8599999999999: 7.7,
#    956.4600000000003: 9.6,
#    957.0699999999999: 12.1,
#    957.6800000000001: 9.6,
#    958.2900000000002: 8.7,
#    958.8999999999999: 7.199999999999999,
#    959.51: 10.6,
#    960.1200000000001: 8.200000000000001,
#    960.7300000000002: 7.7,
#    961.3399999999999: 6.7,
#    961.95: 5.7,
#    962.5600000000002: 4.7,
#    963.1699999999998: 5.7,
#    963.78: 4.2,
#    964.3900000000001: 5.2,
#    965.0000000000002: 4.7,
#    965.6099999999999: 1.7999999999999998}},
#  'UWI_4900523835.txt': {'units': 'm',
#   'x': 40160.0,
#   'y': -32004.0,
#   'tops': {'Sussex Lower Base': 919.8899999999999,
#    'Sussex Upper Base': 915.0099999999998,
#    'Sussex Lower Top': 916.23,
#    'Niobrara': 920.5,
#    'Sussex Upper Top': 911.9699999999998,
#    'Ardmore': 898.56,
#    'Cody': 911.3600000000001},
#   'porosities': {909.5299999999997: 13.0,
#    910.1399999999999: 14.000000000000002,
#    910.75: 20.0,
#    911.3600000000001: 9.5,
#    911.9699999999998: 12.0,
#    912.5799999999999: 12.0,
#    913.19: 11.0,
#    913.7999999999997: 12.5,
#    914.4000000000001: 12.5,
#    915.0099999999998: 11.5,
#    915.6199999999999: 8.0,
#    916.23: 3.5000000000000004,
#    916.8399999999997: 4.5,
#    917.4499999999998: 15.0,
#    918.06: 16.0,
#    918.6700000000001: 16.0,
#    919.2799999999997: 15.0,
#    919.8899999999999: 13.5,
#    920.5: 4.0,
#    921.1100000000001: 6.5,
#    921.7199999999998: 6.0}},
#  '4900523857.txt': {'units': 'm',
#   'x': 39380.0,
#   'y': -31174.0,
#   'tops': {'Ardmore': 897.6299999999999,
#    'Sussex Lower Base': 918.97,
#    'Niobrara': 918.97,
#    'Sussex Upper Top': 910.4300000000001,
#    'Sussex Upper Base': 913.4799999999998,
#    'Cody': 910.4300000000001,
#    'Sussex Lower Top': 914.0899999999999},
#   'porosities': {908.6000000000001: 6.0,
#    909.2099999999998: 6.0,
#    909.8199999999999: 4.0,
#    910.4300000000001: 8.0,
#    911.0400000000002: 12.0,
#    911.6499999999999: 15.5,
#    912.26: 15.0,
#    912.8700000000001: 15.5,
#    913.4799999999998: 11.0,
#    914.0899999999999: 3.0,
#    914.7: 11.0,
#    915.3100000000002: 13.5,
#    915.9199999999998: 13.0,
#    916.53: 13.0,
#    917.1400000000001: 11.0,
#    917.7499999999998: 10.5,
#    918.3599999999999: 8.5,
#    918.97: 3.5000000000000004,
#    919.5800000000002: 4.5}}}

# %%
all_tops['UWI_4900527320.txt'].keys()
# Out:
# dict_keys(['units', 'x', 'y', 'tops', 'porosities'])
